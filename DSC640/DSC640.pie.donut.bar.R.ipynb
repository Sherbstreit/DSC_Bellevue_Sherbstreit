# %%
library(dplyr)
library(readxl)
library(ggplot2)
library(pastecs)
library(reshape2)

# %%
data <- read_excel('obama-approval-ratings.xls')
df <- data.frame(data)
df
# Out:
#    Issue                    Approve Disapprove None
# 1  Race Relations           52      38         10
# 2  Education                49      40         11
# 3  Terrorism                48      45          7
# 4  Energy Policy            47      42         11
# 5  Foreign Affairs          44      48          8
# 6  Environment              43      51          6
# 7  Situation in Iraq        41      53          6
# 8  Taxes                    41      54          5
# 9  Healthcare Policy        40      57          3
# 10 Economy                  38      59          3
# 11 Situation in Afghanistan 36      57          7
# 12 Federal Budget Deficit   31      64          5
# 13 Immigration              29      62          9

# %%
df2 <- as.data.frame(t(as.matrix(df)))
df2
# Out:
#            V1             V2        V3        V4            V5
# Issue      Race Relations Education Terrorism Energy Policy Foreign Affairs
# Approve    52             49        48        47            44
# Disapprove 38             40        45        42            48
# None       10             11         7        11             8
#            V6          V7                V8    V9                V10
# Issue      Environment Situation in Iraq Taxes Healthcare Policy Economy
# Approve    43          41                41    40                38
# Disapprove 51          53                54    57                59
# None        6           6                 5     3                 3
#            V11                      V12                    V13
# Issue      Situation in Afghanistan Federal Budget Deficit Immigration
# Approve    36                       31                     29
# Disapprove 57                       64                     62
# ...

# %%
names(df2) <- as.matrix(df2[1, ])
df2 <- df2[-1, ]
df2[] <- lapply(df2, function(x) type.convert(as.character(x)))
df2
# Out:
#            Race Relations Education Terrorism Energy Policy Foreign Affairs
# Approve    52             49        48        47            44
# Disapprove 38             40        45        42            48
# None       10             11         7        11             8
#            Environment Situation in Iraq Taxes Healthcare Policy Economy
# Approve    43          41                41    40                38
# Disapprove 51          53                54    57                59
# None        6           6                 5     3                 3
#            Situation in Afghanistan Federal Budget Deficit Immigration
# Approve    36                       31                     29
# Disapprove 57                       64                     62
# None        7                        5                      9

# %%
names(df2) <- gsub(" ", "_", names(df2))

# %%
df2
# Out:
#            Race_Relations Education Terrorism Energy_Policy Foreign_Affairs
# Approve    52             49        48        47            44
# Disapprove 38             40        45        42            48
# None       10             11         7        11             8
#            Environment Situation_in_Iraq Taxes Healthcare_Policy Economy
# Approve    43          41                41    40                38
# Disapprove 51          53                54    57                59
# None        6           6                 5     3                 3
#            Situation_in_Afghanistan Federal_Budget_Deficit Immigration
# Approve    36                       31                     29
# Disapprove 57                       64                     62
# None        7                        5                      9

# %%
slices = df2$Race_Relations
lbls = row.names(df2)
pct <- round(slices/sum(slices) * 100)
lbls <- paste(lbls, pct)
lbls <- paste(lbls, "%", sep = "")
pie(slices, labels = lbls, main = "Obama Approval Rating on Race Relations")
# Out:
# Plot with title “Obama Approval Rating on Race Relations”

# %%
ggplot(df2, aes(x = 2, y = Race_Relations, fill = lbls)) +
  geom_bar(stat = 'identity', color = 'white') +
  coord_polar(theta = "y", start = 0)+
  theme_void()+
  xlim(0.5, 2.5) + 
  ggtitle('Obama Approval Rating on Race Relations')
# Out:
# plot without title

# %%
library(reshape2)
df.long<-melt(df)
# Out:
# Warning message in melt(df):
# “The melt generic in data.table has been passed a data.frame and will attempt to redirect to the relevant reshape2 method; please note that reshape2 is deprecated, and this redirection is now deprecated as well. To continue using melt methods from reshape2 while both libraries are attached, e.g. melt.list, you can prepend the namespace like reshape2::melt(df). In the next version, this warning will become an error.”
# Using Issue as id variables

# %%
ggplot(df.long,aes(Issue,value,fill=variable))+
     geom_bar(stat="identity",position="dodge") +
    theme_grey(base_size = 17) +
    ggtitle('Obama Approval Ratings') +
    theme(axis.text.x = element_text(angle = 90, vjust = 0.5, hjust=1))
# Out:
# plot without title

# %%
ggplot(df.long,aes(Issue,value,fill=variable))+
     geom_bar(stat="identity",position="stack") +
    theme_grey(base_size = 17) +
    ggtitle('Obama Approval Ratings') +
    theme(axis.text.x = element_text(angle = 90, vjust = 0.5, hjust=1))
# Out:
# plot without title
