# %%
# import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

# %%
# Open file
df = pd.read_csv("weather_nz.csv")

# %%
df.head()
# Out:
#       DATE  Auckland  Christchurch  Dunedin  Hamilton  Wellington
# 0  2000-01        32            27       40        34          24
# 1  2000-02        37            32       45        39          29
# 2  2000-03        47            42       55        49          39
# 3  2000-04        57            52       65        59          49
# 4  2000-05        67            62       75        69          59

# %%
myFmt = mdates.DateFormatter('%m')
ax.xaxis.set_major_formatter(myFmt)

# %%
df.dtypes
# Out:
# DATE            object
# Auckland         int64
# Christchurch     int64
# Dunedin          int64
# Hamilton         int64
# Wellington       int64
# dtype: object

# %%
df['DATE'] =  pd.to_datetime(df['DATE'], format='%Y-%m')

# %%
df = df.set_index('DATE')

# %%
df.plot(title = 'Temperature by City and Month', figsize=(13,6))
plt.ylabel('Temperature (°F)')
# Out:
# Text(0, 0.5, 'Temperature (°F)')

# %%
df2 = df.drop(['Christchurch', 'Dunedin', 'Hamilton', 'Wellington'], axis=1)
df2.plot(title = 'Temperature in Auckland by Month', figsize=(13,6),
         drawstyle="steps-post", linewidth=2, legend=False)
plt.ylabel('Temperature (°F)')
# Out:
# Text(0, 0.5, 'Temperature (°F)')
